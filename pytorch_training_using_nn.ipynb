# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class MySimpleImputer(nn.Module):

  def __init__(self,num_features):
    super().__init__()

    self.linear = nn.Linear(num_features,1)
    self.sigmoid = nn.Sigmoid()

  def forward(self,num_features):

    out = self.linear(features)
    out = self.sigmoid(out)

    return out

# %% [markdown]
# ### Important Parameters

# %%
learning_rate = 0.1
epochs = 75

# %% [markdown]
# ### Loss function :- Binary Cross Entropy

# %%
loss_function = nn.BCELoss()

# %%
features = torch.rand(10,5)
y = torch.randint(0, 2, (10, 1)).float()

# %%
model = MySimpleImputer(features.shape[1])
# optimizer
optimizer = optim.SGD(model.parameters(),lr=learning_rate)

for epoch in range(epochs):

  #forward pass
  y_pred = model(features)

  # loss calculation
  loss = loss_function(y_pred,y)

  # clearing gradients
  optimizer.zero_grad()

  # backward pass
  loss.backward()

  # paramters update
  optimizer.step()

  print(f"Epochs : {epoch+1}, Loss : {loss.item()}")
# Out:
# Epochs : 1, Loss : 0.6864681243896484
# Epochs : 2, Loss : 0.6827749609947205
# Epochs : 3, Loss : 0.6793660521507263
# Epochs : 4, Loss : 0.6762145161628723
# Epochs : 5, Loss : 0.6732954382896423
# Epochs : 6, Loss : 0.6705867052078247
# Epochs : 7, Loss : 0.6680673956871033
# Epochs : 8, Loss : 0.6657193899154663
# Epochs : 9, Loss : 0.6635256409645081
# Epochs : 10, Loss : 0.6614709496498108
# Epochs : 11, Loss : 0.6595414280891418
# Epochs : 12, Loss : 0.6577249765396118
# Epochs : 13, Loss : 0.6560100317001343
# Epochs : 14, Loss : 0.654386579990387
# Epochs : 15, Loss : 0.6528456211090088
# Epochs : 16, Loss : 0.6513788104057312
# Epochs : 17, Loss : 0.6499788761138916
# Epochs : 18, Loss : 0.6486390829086304
# Epochs : 19, Loss : 0.6473535299301147
# Epochs : 20, Loss : 0.6461169123649597
# Epochs : 21, Loss : 0.644924521446228
# Epochs : 22, Loss : 0.643771767616272
# Epochs : 23, Loss : 0.6426550149917603
# Epochs : 24, Loss : 0.6415707468986511
# Epochs : 25, Loss : 0.6405158042907715
# Epochs : 26, Loss : 0.6394875645637512
# Epochs : 27, Loss : 0.6384831666946411
# Epochs : 28, Loss : 0.6375006437301636
# Epochs : 29, Loss : 0.6365381479263306
# Epochs : 30, Loss : 0.6355934143066406
# Epochs : 31, Loss : 0.6346652507781982
# Epochs : 32, Loss : 0.6337519884109497
# Epochs : 33, Loss : 0.6328524351119995
# Epochs : 34, Loss : 0.6319652795791626
# Epochs : 35, Loss : 0.6310898065567017
# Epochs : 36, Loss : 0.6302248239517212
# Epochs : 37, Loss : 0.6293693780899048
# Epochs : 38, Loss : 0.6285229921340942
# Epochs : 39, Loss : 0.6276849508285522
# Epochs : 40, Loss : 0.6268545389175415
# Epochs : 41, Loss : 0.6260312795639038
# Epochs : 42, Loss : 0.6252145767211914
# Epochs : 43, Loss : 0.6244041919708252
# Epochs : 44, Loss : 0.623599648475647
# Epochs : 45, Loss : 0.6228005290031433
# Epochs : 46, Loss : 0.6220066547393799
# Epochs : 47, Loss : 0.6212176084518433
# Epochs : 48, Loss : 0.6204331517219543
# Epochs : 49, Loss : 0.6196531653404236
# Epochs : 50, Loss : 0.6188773512840271
# Epochs : 51, Loss : 0.6181055307388306
# Epochs : 52, Loss : 0.6173375844955444
# Epochs : 53, Loss : 0.6165733337402344
# Epochs : 54, Loss : 0.6158125996589661
# Epochs : 55, Loss : 0.6150554418563843
# Epochs : 56, Loss : 0.614301323890686
# Epochs : 57, Loss : 0.6135506629943848
# Epochs : 58, Loss : 0.6128031015396118
# Epochs : 59, Loss : 0.6120585799217224
# Epochs : 60, Loss : 0.6113169193267822
# Epochs : 61, Loss : 0.6105783581733704
# Epochs : 62, Loss : 0.6098424196243286
# Epochs : 63, Loss : 0.6091093420982361
# Epochs : 64, Loss : 0.6083791255950928
# Epochs : 65, Loss : 0.6076514720916748
# Epochs : 66, Loss : 0.6069265604019165
# Epochs : 67, Loss : 0.6062041521072388
# Epochs : 68, Loss : 0.6054844260215759
# Epochs : 69, Loss : 0.6047671437263489
# Epochs : 70, Loss : 0.6040522456169128
# Epochs : 71, Loss : 0.6033400893211365
# Epochs : 72, Loss : 0.6026301980018616
# Epochs : 73, Loss : 0.6019227504730225
# Epochs : 74, Loss : 0.6012178063392639
# Epochs : 75, Loss : 0.6005151867866516

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

# %%
summary(model,input_size=(10,5))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MySimpleImputer                          [10, 1]                   --
# ├─Linear: 1-1                            [10, 1]                   6
# ├─Sigmoid: 1-2                           [10, 1]                   --
# ==========================================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
